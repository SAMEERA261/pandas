# %%
import numpy as np,pandas as  pd

# %%
import matplotlib.pyplot as plt,seaborn as sns,sklearn

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe(include='all').T
# Out:
#               count unique     top freq      mean       std  min  25%   50%  \
# sepal_length  150.0    NaN     NaN  NaN  5.843333  0.828066  4.3  5.1   5.8
# sepal_width   150.0    NaN     NaN  NaN  3.057333  0.435866  2.0  2.8   3.0
# petal_length  150.0    NaN     NaN  NaN     3.758  1.765298  1.0  1.6  4.35
# petal_width   150.0    NaN     NaN  NaN  1.199333  0.762238  0.1  0.3   1.3
# species         150      3  setosa   50       NaN       NaN  NaN  NaN   NaN
#
#               75%  max
# sepal_length  6.4  7.9
# sepal_width   3.3  4.4
# petal_length  5.1  6.9
# petal_width   1.8  2.5
# species       NaN  NaN

# %%
df['sepal_length'].plot()
# Out:
# <Axes: >

# %%
df['sepal_length'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df[df['species']=='setosa']['sepal_length'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df[df['species']=='virginica']['sepal_length'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df[df['species']=='setosa']['petal_length'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['petal_length'].plot(kind='kde')#for every spices
# Out:
# <Axes: ylabel='Density'>

# %%
df[df['species']=='virginica']['petal_length'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
print(df[df['species']=='setosa']['sepal_length'].mean())
print(df[df['species']=='setosa']['sepal_width'].mean())
# Out:
# 5.006
# 3.428

# %%
(df[df['species']=='virginica']['sepal_length'].mean())
# Out:
# 6.587999999999998

# %%
df['species'].unique(),df['species'].nunique()
# Out:
# (array(['setosa', 'versicolor', 'virginica'], dtype=object), 3)

# %%
#df.mean()

# %%
df['species'].value_counts()#this output is series
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
type(df['species'].value_counts())
# Out:
# pandas.core.series.Series

# %%
df['species'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='species'>

# %%
df['petal_length'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df['species']=='virginica']['sepal_length'].plot(kind='hist',color='yellow')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df['species']=='virginica']['sepal_length'].plot(kind='bar',color='red')
# Out:
# <Axes: >

# %%
df['species'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df[df['species']=='virginica']['sepal_length'].plot(kind='pie')
# Out:
# <Axes: ylabel='sepal_length'>

# %%
df.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %%
df[df['petal_length']>=3.758000]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 53            5.5          2.3           4.0          1.3  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 147           6.5          3.0           5.2          2.0   virginica
# 148           6.2          3.4           5.4          2.3   virginica
# 149           5.9          3.0           5.1          1.8   virginica
#
# [93 rows x 5 columns]

# %%
df[df['petal_length']>=3.758000]['species'].value_counts()
# Out:
# species
# virginica     50
# versicolor    43
# Name: count, dtype: int64

# %%
df.sort_values(by=['sepal_length'])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
df.sort_values(by=['sepal_length'],ascending=False)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# ..            ...          ...           ...          ...        ...
# 41            4.5          2.3           1.3          0.3     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
#
# [150 rows x 5 columns]

# %%
df.sort_values(by=['sepal_length','petal_length'],ascending=False)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# ..            ...          ...           ...          ...        ...
# 41            4.5          2.3           1.3          0.3     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
#
# [150 rows x 5 columns]

# %%
gdf=pd.read_csv(r'C:\Users\Sam\.anaconda\german_credit_data_1.csv')
gdf
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0             0   67    male    2     own             NaN           little
# 1             1   22  female    2     own          little         moderate
# 2             2   49    male    1     own          little              NaN
# 3             3   45    male    2    free          little           little
# 4             4   53    male    2    free          little           little
# ..          ...  ...     ...  ...     ...             ...              ...
# 995         995   31  female    1     own          little              NaN
# 996         996   40    male    3     own          little           little
# 997         997   38    male    2     own          little              NaN
# 998         998   23    male    2    free          little           little
# 999         999   27    male    2     own        moderate         moderate
#
#      Credit amount  Duration              Purpose
# ...

# %%
gdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1000 non-null   int64
#  1   Age               1000 non-null   int64
#  2   Sex               1000 non-null   object
#  3   Job               1000 non-null   int64
#  4   Housing           1000 non-null   object
#  5   Saving accounts   817 non-null    object
#  6   Checking account  606 non-null    object
#  7   Credit amount     1000 non-null   int64
#  8   Duration          1000 non-null   int64
#  9   Purpose           1000 non-null   object
# dtypes: int64(5), object(5)
# memory usage: 78.3+ KB

# %%
gdf.drop(columns=['Unnamed: 0'],inplace=True)

# %%
gdf['Job']=gdf['Job'].astype('object')

# %%
s=gdf.describe(include='all').T
s
# Out:
#                    count unique     top   freq      mean          std    min  \
# Age               1000.0    NaN     NaN    NaN    35.546    11.375469   19.0
# Sex                 1000      2    male    690       NaN          NaN    NaN
# Job               1000.0    4.0     2.0  630.0       NaN          NaN    NaN
# Housing             1000      3     own    713       NaN          NaN    NaN
# Saving accounts      817      4  little    603       NaN          NaN    NaN
# Checking account     606      3  little    274       NaN          NaN    NaN
# Credit amount     1000.0    NaN     NaN    NaN  3271.258  2822.736876  250.0
# Duration          1000.0    NaN     NaN    NaN    20.903    12.058814    4.0
# Purpose             1000      8     car    337       NaN          NaN    NaN
#
#                      25%     50%      75%      max
# Age                 27.0    33.0     42.0     75.0
# Sex                  NaN     NaN      NaN      NaN
# ...

# %% [markdown]
# # priliminary data analysis on german credit data frame:-

# %% [markdown]
# #### The main diffrence between cheking accounts and saving accounts is that -
# * checking account is being used for all type of transactions and can be used  for deposits,pay bills,transfer money between accounts and they have no limits on online transfers ,ATM transactions,cheques,and debit card.
# * savings accounts have no online bill payments no debit cards payments:withdrawal and online transfers are limited to only 6 times a month.its not subjected to risk savings will be done in small amounts,and will be earned small amount of intrest .
# ### in the above data we can see the below columns that have been taken for analysis:
# * Age (numeric)
# * Sex (text: male, female)
# * Job (numeric: 0 - unskilled and non-resident, 1 - unskilled and resident, 2 - skilled, 3 - highly skilled)
# * Housing (text: own, rent, or free)
# * Saving accounts (text - little, moderate, quite rich, rich)
# * Checking account (numeric, in DM - Deutsch Mark)
# * Credit amount (numeric, in DM)
# * Duration (numeric, in month)
# * Purpose (text: car, furniture/equipment, radio/TV, domestic appliances, repairs, education, business, vacation/others)

# %% [markdown]
# ### "German Credit Risk" typically refers to the assessment or evaluation of the credit worthiness of individuals or entities in Germany. Credit risk refers to the potential of financial loss resulting from the failure of a borrower to repay a loan or meet their financial obligations.
# * The assessment helps financial institutions make informed decisions about whether to grant credit, and if so, under what terms (interest rate, loan amount, repayment period, etc.). Managing and mitigating credit risk is crucial for lenders to avoid financial losses and ensure the stability of their operations.
#
# * Keep in mind that the term "German Credit Risk" might also refer to specific datasets or studies related to credit risk analysis in the context of Germany.
#
#
# #### how to remove this nan values

# %%
x= gdf[(gdf['Sex'] == 'female') & (gdf['Saving accounts']=='quite rich') | (gdf['Saving accounts']=='rich') & (gdf['Age'].between(20,30)) ]

# %%
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 47    23  female   0    rent      quite rich           little           1352
# 67    22    male   2     own            rich         moderate           1007
# 118   23  female   2     own      quite rich           little           4281
# 136   27    male   2     own            rich              NaN           8613
# 140   27    male   0     own            rich             rich            709
# 153   29  female   2    rent            rich         moderate           7758
# 167   20  female   2     own            rich         moderate           1577
# 226   27    male   2     own            rich         moderate          10961
# 244   35  female   1     own      quite rich              NaN           3447
# 271   37  female   2    rent      quite rich              NaN           1402
# 280   23    male   2    rent            rich              NaN           3368
# ...

# %%
x.sort_values(by=['Purpose'],ascending=False)
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 226   27    male   2     own            rich         moderate          10961
# 136   27    male   2     own            rich              NaN           8613
# 945   30  female   2     own      quite rich         moderate           8358
# 153   29  female   2    rent            rich         moderate           7758
# 870   40  female   2     own      quite rich              NaN           7678
# 860   27    male   2     own            rich              NaN           5804
# 705   35  female   2    free      quite rich              NaN           5324
# 118   23  female   2     own      quite rich           little           4281
# 952   28  female   2    rent      quite rich         moderate           4113
# 347   23  female   0    rent      quite rich         moderate           3758
# 244   35  female   1     own      quite rich              NaN           3447
# ...

# %%
gdf['Purpose'].value_counts().plot(kind='bar',color='red')
# Out:
# <Axes: xlabel='Purpose'>

# %%
gdf['Purpose'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Purpose'>

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...
